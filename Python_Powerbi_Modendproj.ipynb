# %%
#IMPORTING NECSSSARY MODULES

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# READING THE FILE
df=pd.read_csv("covid_19_clean_complete.csv")
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
# Column names in data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
## Data Preperation and Cleaning

# %%
len(df.columns)
# Out:
# 10

# %%
df.shape
# Out:
# (49068, 10)

# %%
df.head(5)
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
# To find out if there is any null values
## (Checking for null values in any of the columns.)
df.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %% [markdown]
# ## No Null Values

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# To find out column names
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
##To view the statistical values of numerical columns
df.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %% [markdown]
# ## Handling the missing values

# %%
df.isna().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
df.rename(columns = {'Country/Region':'Country'}, inplace=True)

# %%
df
# Out:
#       Province/State                Country        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
Top_Countries=df.groupby('Country').agg({'Confirmed':'sum'}).sort_values(by="Confirmed",ascending=False)
Top_Countries
# Out:
#                        Confirmed
# Country
# US                     224345948
# Brazil                  89524967
# Russia                  45408411
# India                   40883464
# Spain                   27404045
# ...                          ...
# Saint Kitts and Nevis       1772
# Greenland                   1507
# Holy See                    1356
# Papua New Guinea            1185
# Western Sahara               901
#
# [187 rows x 1 columns]

# %%
# To plot the top affected countries by range 10
Top_confirmed=Top_Countries.iloc[:10]
Top_confirmed
# Out:
#                 Confirmed
# Country
# US              224345948
# Brazil           89524967
# Russia           45408411
# India            40883464
# Spain            27404045
# United Kingdom   26748587
# Italy            26745145
# France           21210926
# Germany          21059152
# Iran             19339267

# %%
labels = Top_Countries.index[:10]  # Top 10 countries
sizes = Top_Countries['Confirmed'][:10]  # Corresponding confirmed case numbers

# Plotting the pie chart
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Top 10 Countries by Confirmed Cases')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the pie chart
plt.show()

# %%
# to view the count of recoveries
top_Recovery=df.groupby('Country').agg({'Recovered':'sum'}).sort_values(by="Recovered",ascending=False)
top_Recovery
# Out:
#              Recovered
# Country
# US            56353416
# Brazil        54492873
# Russia        25120448
# India         23783720
# Germany       17107839
# ...                ...
# Timor-Leste          0
# Mozambique           0
# Syria                0
# Sweden               0
# Canada               0
#
# [187 rows x 1 columns]

# %%
top10_recovery=top_Recovery.iloc[:10]
top10_recovery
# Out:
#          Recovered
# Country
# US        56353416
# Brazil    54492873
# Russia    25120448
# India     23783720
# Germany   17107839
# Italy     15673910
# Iran      15200895
# Spain     15093583
# Turkey    13345389
# Chile     13292593

# %%
#  ploting the countries with highest recovery


top10_recovery.plot(kind='bar')
plt.xlabel( "Recovery Rate" )

# Set label for y-axis
plt.ylabel( "Top Countries" )

# Set title for figure
plt.title( "Top 10 countries with highest recovery rate" )
# Out:
# Text(0.5, 1.0, 'Top 10 countries with highest recovery rate')

# %%
Country_confm_recovery= df.groupby('Country').agg({'Confirmed': 'sum', 'Recovered': 'sum', 'Deaths': 'sum'}).reset_index()
                                  
Country_confm_recovery
df1= pd.DataFrame(Country_confm_recovery)
df1
# Out:
#                 Country  Confirmed  Recovered  Deaths
# 0           Afghanistan    1936390     798240   49098
# 1               Albania     196702     118877    5708
# 2               Algeria    1179755     755897   77972
# 3               Andorra      94404      69074    5423
# 4                Angola      22662       6573    1078
# ..                  ...        ...        ...     ...
# 182  West Bank and Gaza     233461      61124    1370
# 183      Western Sahara        901        648      63
# 184               Yemen      67180      23779   17707
# 185              Zambia     129421      83611    2643
# 186            Zimbabwe      50794      12207     881
#
# [187 rows x 4 columns]

# %%
top10_death=df.groupby('Country').agg({'Deaths':'sum'}).sort_values(by="Deaths",ascending=False)
top10_death
# Out:
#                   Deaths
# Country
# US              11011411
# United Kingdom   3997775
# Brazil           3938034
# Italy            3707717
# France           3048524
# ...                  ...
# Bhutan                 0
# Mongolia               0
# Timor-Leste            0
# Seychelles             0
# Greenland              0
#
# [187 rows x 1 columns]

# %%
Top_death=top10_death.iloc[:10]
Top_death
# Out:
#                   Deaths
# Country
# US              11011411
# United Kingdom   3997775
# Brazil           3938034
# Italy            3707717
# France           3048524
# Spain            3033030
# Mexico           1728277
# India            1111831
# Iran             1024136
# Belgium           963679

# %%
#  ploting the top models
plt.figure(figsize=(8,6))
plt.xticks(rotation=75)
sns.barplot(x=Top_death.index, y='Deaths',data=Top_death)
plt.xlabel( "Countries")

# Set label for y-axis
plt.ylabel( "Count of Deaths" )

# Set title for figure
plt.title( "Highest Death reported countries " )
plt.show()
